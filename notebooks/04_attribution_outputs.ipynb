# %% [markdown]
# # 04 - RBA outputs
# Generate contribution tables, ROI summaries, and plots.

# %%
import sys
from pathlib import Path

# Make project importable in notebooks
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import pandas as pd
import numpy as np
