# %% [markdown]
# # 02 - Feature engineering
# Apply ad stock + saturation transformations; create seasonality and other controls.

# %%
import sys
from pathlib import Path

# Make project importable in notebooks
PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import pandas as pd
import numpy as np
